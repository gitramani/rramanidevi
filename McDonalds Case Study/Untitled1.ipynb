# %%
import pandas as pd

# Load the McDonald's dataset from the appropriate path
dataset_path = r"C:\Users\RAMANIDEVI\Downloads\McDonalds Case Study\McDonalds Case Study.csv"  # Update with the correct file name

# Read the dataset
try:
    mcdonalds = pd.read_csv(dataset_path)  # Use pd.read_excel() if it's an Excel file

    # Display column names
    print("Column names:")
    print(mcdonalds.columns.tolist())

    # Display the dimensions of the dataset
    print("\nDataset dimensions:")
    print(mcdonalds.shape)

    # Display the first 3 rows of the dataset
    print("\nFirst 3 rows of the dataset:")
    print(mcdonalds.head(3))
except FileNotFoundError:
    print("Dataset file not found. Please check if the path and filename are correct.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# C:\Users\RAMANIDEVI\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Dataset file not found. Please check if the path and filename are correct.

# %%
import os

# Specify the path to the directory
directory_path = r"C:\Users\RAMANIDEVI\Downloads\McDonalds Case Study"

# List files in the directory
if os.path.exists(directory_path):
    files = os.listdir(directory_path)
    print("Files in directory:")
    for file in files:
        print(file)
else:
    print("Directory not found. Please check the path.")
# Out:
# Files in directory:
# McDonalds Case Study

# %%
dataset_path = r"C:\Users\RAMANIDEVI\Downloads\McDonalds Case Study\McDonalds Case Study.csv"

# %%
import pandas as pd

# Specify the correct path and filename here
dataset_path = r"C:\Users\RAMANIDEVI\Downloads\McDonalds Case Study\McDonalds Case Study.csv"  # Update with your actual filename

try:
    # Reading the dataset
    if dataset_path.endswith('.csv'):
        mcdonalds = pd.read_csv(dataset_path)
    elif dataset_path.endswith(('.xls', '.xlsx')):
        mcdonalds = pd.read_excel(dataset_path)
    else:
        print("Unsupported file format.")
        mcdonalds = None  # Define mcdonalds as None to avoid "not defined" error
    
    # Only proceed if mcdonalds was successfully created
    if mcdonalds is not None:
        # Display information and preview
        print("Column names:", mcdonalds.columns.tolist())
        print("Dataset dimensions:", mcdonalds.shape)
        print("First 3 rows:\n", mcdonalds.head(3))

except FileNotFoundError:
    print("Dataset file not found. Please check if the path and filename are correct.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Dataset file not found. Please check if the path and filename are correct.
